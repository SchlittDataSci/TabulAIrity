# %%
import sys,os
sys.path.append('../src/tabulairity/')

import pandas as pd
import numpy as np
import osmnx as ox
import geopandas as gpd
import tabulairity as tb

import json
import ast

from dateutil import parser
from time import sleep
from shapely.geometry import Point
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
tb.modelName = 'gpt-4'

# %% [markdown]
# # Test Case 2: WHO Disease Outbreak News
# * Scrapes DON reports
# * Extracts data to standardized format

# %%
def extractDON(html):
    soup = BeautifulSoup(html)
    title = soup.find(class_='don-title').text.strip()
    extracted = {'title':title}

    donSectionHeadings = soup.find_all('h3', class_='don-section')
    for h3Heading in donSectionHeadings:
        donContentDiv = h3Heading.find_next('div',class_='don-content')
        if donContentDiv:
            content = donContentDiv.text.strip()
            extracted[h3Heading.text.strip()] = content
    return extracted

# %%
reportRange2022 = [f'2022-DON{report}' for report in range(390,433)]
reportRange2023 = [f'2023-DON{report}' for report in range(432,497)]
unsorted = ['2022-DON435']
reportRange = sorted(list(set(reportRange2022 + reportRange2023 + unsorted)))
urlPrefix = 'https://www.who.int/emergencies/disease-outbreak-news/item/'
urls = [f'{urlPrefix}{report}' for report in reportRange]

# %%
donTableRef = 'input/DONPages.csv'

if not os.path.exists(donTableRef):
    pages = dict()
    for url in urls:
        try:
            html = tb.cachePage(url)
            pages[url.split('/')[-1]] = extractDON(html)
        except:
            print(f"Failed for page: {url}")
        
    DONPages = pd.DataFrame(pages).T
    DONPages.loc[:,'URL'] = urlPrefix + DONPages.index
    DONPages.to_csv(donTableRef)
else:
    DONPages = pd.read_csv(donTableRef,index_col=0)

# %%
DONPages
# Out:
#                                                          title  \
# 2022-DON390  Multi-country monkeypox outbreak: situation up...
# 2022-DON391                                 Cholera - Pakistan
# 2022-DON392  Multi-country monkeypox outbreak: situation up...
# 2022-DON393  Multi-country monkeypox outbreak: situation up...
# 2022-DON394  Severe acute hepatitis of unknown aetiology in...
# ...                                                        ...
# 2023-DON492                                Diphtheria - Guinea
# 2023-DON493  Mpox (monkeypox)- Democratic Republic of the C...
# 2023-DON494  Upsurge of respiratory illnesses among childre...
# 2023-DON495                Avian Influenza A (H5N1) - Cambodia
# 2023-DON496  Influenza A(H1N2) variant virus infection - Un...
#
#                                   Description of the Situation  \
# 2022-DON390  The current publication of Disease Outbreak Ne...
# 2022-DON391  Outbreak at a glanceIn Pakistan, cholera is en...
# 2022-DON392  This current Disease Outbreak News on the mult...
# 2022-DON393  This current Disease Outbreak News on the mult...
# 2022-DON394  Outbreak at a glance As of 22 June 2022, 33 co...
# ...                                                        ...
# 2023-DON492  On 5 September 2023, the Ministry of Health no...
# 2023-DON493  From 1 January through 12 November 2023, a tot...
# 2023-DON494  Since mid-October 2023, the World Health Organ...
# 2023-DON495  The Ministry of Health of Cambodia notified WH...
# 2023-DON496  On 25 November 2023, under the IHR (2005), the...
#
#                                         Public Health Response  \
# 2022-DON390  WHO continues to support sharing of informatio...
# 2022-DON391  In response to the outbreak, the provincial he...
# 2022-DON392  WHO continues to support sharing of informatio...
# 2022-DON393  WHO continues to support sharing of informatio...
# 2022-DON394  Epidemiological, clinical, laboratory, histopa...
# ...                                                        ...
# 2023-DON492  Guinea has strengthened epidemiological survei...
# 2023-DON493  Emergency coordination: The Ministry of Public...
# 2023-DON494  Since mid-October, in addition to enhancing di...
# 2023-DON495  The Ministry of Health's national and sub-nati...
# 2023-DON496  WHO is closely collaborating with national aut...
#
#                                            WHO Risk Assessment  \
# 2022-DON390  Currently, the public health risk at the globa...
# 2022-DON391  The risk of potential international spread fro...
# 2022-DON392  Currently, the public health risk at the globa...
# 2022-DON393  Currently, the public health risk at the globa...
# 2022-DON394  The risk at the global level is currently asse...
# ...                                                        ...
# 2023-DON492  Diphtheria is a vaccine-preventable disease ca...
# 2023-DON493  From 1 January to 12 November 2023, there has ...
# 2023-DON494  In the current outbreak of respiratory illness...
# 2023-DON495  From 2003 to 27 November 2023, a total of 882 ...
# 2023-DON496  Influenza viruses circulate in swine populatio...
#
#                                                     WHO Advice  \
# 2022-DON390  The advice provided hereafter by the WHO on ac...
# 2022-DON391  WHO recommends strengthening of the disease su...
# 2022-DON392  The advice provided hereafter by the WHO on ac...
# 2022-DON393  The advice provided hereafter by the WHO on ac...
# 2022-DON394  Laboratory testing WHO has developed interim g...
# ...                                                        ...
# 2023-DON492  The control of diphtheria is based on primary ...
# 2023-DON493  All countries, including their health authorit...
# 2023-DON494  Based on the available information, WHO recomm...
# 2023-DON495  This event does not change the current WHO rec...
# 2023-DON496  People with any respiratory symptoms should co...
#
#                                            Further Information  \
# 2022-DON390  WHO Guidance and Public Health Recommendations...
# 2022-DON391  Cholera fact sheet Weekly Epidemiological Reco...
# 2022-DON392  For more information on monkeypox, please see:...
# 2022-DON393  WHO Guidance and Public Health Recommendations...
# 2022-DON394  Joint ECDC-WHO Regional Office for Europe Hepa...
# ...                                                        ...
# 2023-DON492  WHO diphtheria page: https://www.who.int/teams...
# 2023-DON493  WHO interim technical guidance:https://www.who...
# 2023-DON494  ProMed article. Undiagnosed pneumonia – China:...
# 2023-DON495  MOH Cambodia press release on official Faceboo...
# 2023-DON496  UK Health Security Agency Press Release: UKHSA...
#
#                                          Situation at a Glance  \
# 2022-DON390                                                NaN
# 2022-DON391                                                NaN
# 2022-DON392                                                NaN
# 2022-DON393                                                NaN
# 2022-DON394                                                NaN
# ...                                                        ...
# 2023-DON492  On 5 September 2023, the Ministry of Health no...
# 2023-DON493  Mpox is an infectious disease caused by monkey...
# 2023-DON494                                                NaN
# 2023-DON495  Between 24 and 25 November 2023, the Ministry ...
# 2023-DON496  On 25 November 2023, the International Health ...
#
#                                                   Epidemiology  \
# 2022-DON390                                                NaN
# 2022-DON391                                                NaN
# 2022-DON392                                                NaN
# 2022-DON393                                                NaN
# 2022-DON394                                                NaN
# ...                                                        ...
# 2023-DON492  Diphtheria is a highly contagious vaccine-prev...
# 2023-DON493  Mpox (monkeypox) is an infectious disease caus...
# 2023-DON494                                                NaN
# 2023-DON495  Animal influenza viruses normally circulate in...
# 2023-DON496  Influenza A viruses are enzootic in swine popu...
#
#                                                            URL
# 2022-DON390  https://www.who.int/emergencies/disease-outbre...
# 2022-DON391  https://www.who.int/emergencies/disease-outbre...
# 2022-DON392  https://www.who.int/emergencies/disease-outbre...
# 2022-DON393  https://www.who.int/emergencies/disease-outbre...
# 2022-DON394  https://www.who.int/emergencies/disease-outbre...
# ...                                                        ...
# 2023-DON492  https://www.who.int/emergencies/disease-outbre...
# 2023-DON493  https://www.who.int/emergencies/disease-outbre...
# 2023-DON494  https://www.who.int/emergencies/disease-outbre...
# 2023-DON495  https://www.who.int/emergencies/disease-outbre...
# 2023-DON496  https://www.who.int/emergencies/disease-outbre...
#
# [102 rows x 9 columns]

# %%
chatFx = {'isYes':lambda x,y:tb.ynToBool(x),
          'isNo':lambda x,y:not tb.ynToBool(x),
          'getYN':lambda x,y:tb.getYN(x),
          'parseDate':lambda x,y: parser.parse(x),
          'geocodeOne':lambda x,y: tb.cacheGeocode(x),
          'geocodeMany':lambda x,y: [tb.cacheGeocode(i.strip()) for i in x.split(',')],
          'castInt':lambda x,y: int(x),
          'loadJson':lambda x,y: json.loads(x),
          'standardizeList':lambda x,y: x.replace('*','-')}

# %%
DONNet = pd.read_csv('networks/DONExtraction.csv')
chatGraph = tb.buildChatNet(DONNet,show=True)


results = dict()
for DON,textData in DONPages[:10].iterrows():
    print(DON)
    if True:
        result = tb.walkChatNet(chatGraph,
                             fxStore = chatFx,
                             varStore = textData,
                             verbosity = 0)
        #sleep(.5)
        results[DON] = result
    else:
        print("Failed for",DON)
    
temp = pd.DataFrame(results)
temp = temp[~temp.index.str.contains('prompt')]
temp = temp[~temp.index.str.contains('-')]

extracted = ['title',
             'Single Pathogen',
             'Multiple Pathogens',
             'Reporting Date',
             'Reporting Agency',
             'Index Date',
             'Case Count',
             'Death Count',
             'Check Pathogen',
             'Location',
             'Single Location',
             'Multiple Locations',
             'Risk Factors',
             'Modes of Transmission',
             'Start',
             'R0',
             'URL']
extracted = [i for i in extracted if i in temp.index]
prepped = temp.loc[extracted,:]
prepped
# Out:
# 2022-DON390
# 2022-DON391
# 2022-DON392
# 2022-DON393
# 2022-DON394
# 2022-DON395
# 2022-DON396
# 2022-DON398
# 2022-DON400
# 2022-DON401
#                                                              2022-DON390  \
# title                  Multi-country monkeypox outbreak: situation up...
# Single Pathogen                                                Monkeypox
# Multiple Pathogens                                                   NaN
# Reporting Date                                                05-13-2022
# Reporting Agency                         World Health Organization (WHO)
# Index Date                                                    05-13-2022
# Case Count                                                           523
# Death Count                                                           66
# Check Pathogen                                                       yes
# Location               Europe, North America, Nigeria, WHO European R...
# Multiple Locations     [[51.0, 10.0], [51.0000002, -109.0], [9.600035...
# Risk Factors           - Frequent encounters between persons in close...
# Modes of Transmission  - Direct contact with infected person\n- Sexua...
# Start                                                                yes
# R0                                                            [0.8, 1.0]
# URL                    https://www.who.int/emergencies/disease-outbre...
#
#                                                              2022-DON391  \
# title                                                 Cholera - Pakistan
# Single Pathogen                                                  Cholera
# Multiple Pathogens                                                   NaN
# Reporting Date                                                04-26-2022
# Reporting Agency                    National IHR Focal Point of Pakistan
# Index Date                                                           NaN
# Case Count                                                           290
# Death Count                                                            9
# Check Pathogen                                                       yes
# Location               Pakistan, Sindh Province, Balochistan Province...
# Multiple Locations     [[30.3308401, 71.247499], [33.9789467, 71.4397...
# Risk Factors           - Proximity to transportation hubs and border ...
# Modes of Transmission                                        None noted.
# Start                                                                 no
# R0                                                            [1.0, 4.0]
# URL                    https://www.who.int/emergencies/disease-outbre...
#
#                                                              2022-DON392  \
# title                  Multi-country monkeypox outbreak: situation up...
# Single Pathogen                                                Monkeypox
# Multiple Pathogens                                                   NaN
# Reporting Date                                                05-13-2022
# Reporting Agency                                                     WHO
# Index Date                                                           NaN
# Case Count                                                           505
# Death Count                                                           72
# Check Pathogen                                                       yes
# Location               Americas, Europe, Eastern Mediterranean, Weste...
# Multiple Locations     [[-13.6154418, -73.1349655], [51.0, 10.0], [35...
# Risk Factors           - Men self-identified as part of extended sexu...
# Modes of Transmission  - Direct contact (e.g., face-to-face, skin-to-...
# Start                                                                 no
# R0                                                            [0.8, 1.0]
# URL                    https://www.who.int/emergencies/disease-outbre...
#
#                                                              2022-DON393  \
# title                  Multi-country monkeypox outbreak: situation up...
# Single Pathogen                                                Monkeypox
# Multiple Pathogens                                                   NaN
# Reporting Date                                                01-01-2022
# Reporting Agency                         World Health Organization (WHO)
# Index Date                                                    01-01-2022
# Case Count                                                          2103
# Death Count                                                            1
# Check Pathogen                                                       yes
# Location               Americas, Africa, Europe, Eastern Mediterranea...
# Multiple Locations     [[-13.6154418, -73.1349655], [11.5024338, 17.7...
# Risk Factors           - Self-identifying men who have sex with men p...
# Modes of Transmission  - Direct contact with an infected person (face...
# Start                                                                yes
# R0                                                            [0.8, 1.0]
# URL                    https://www.who.int/emergencies/disease-outbre...
#
#                                                              2022-DON394  \
# title                  Severe acute hepatitis of unknown aetiology in...
# Single Pathogen                                                      NaN
# Multiple Pathogens                  ['SARS-CoV-2', 'Adenovirus type 41']
# Reporting Date                                                04-05-2022
# Reporting Agency                         World Health Organization (WHO)
# Index Date                                                    04-05-2022
# Case Count                                                           270
# Death Count                                                           18
# Check Pathogen                                                        no
# Location               United Kingdom, Scotland, United States of Ame...
# Multiple Locations     [[54.7023545, -3.2765753], [56.7861112, -4.114...
# Risk Factors                                                         NaN
# Modes of Transmission                                                NaN
# Start                                                                yes
# R0                                                                   NaN
# URL                    https://www.who.int/emergencies/disease-outbre...
#
#                                                              2022-DON395  \
# title                         Wild poliovirus type 1 (WPV1) - Mozambique
# Single Pathogen                            Wild Poliovirus Type 1 (WPV1)
# Multiple Pathogens                                                   NaN
# Reporting Date                                                05-15-2022
# Reporting Agency                         Global Polio Laboratory Network
# Index Date                                                           NaN
# Case Count                                                             1
# Death Count                                                            0
# Check Pathogen                                                       yes
# Location               Mozambique, Pakistan, Malawi, South Africa, Zi...
# Multiple Locations     [[-19.302233, 34.9144977], [30.3308401, 71.247...
# Risk Factors           - Persisting sub-optimal national immunity\n- ...
# Modes of Transmission                                        None noted.
# Start                                                                 no
# R0                                                            [5.0, 7.0]
# URL                    https://www.who.int/emergencies/disease-outbre...
#
#                                                              2022-DON396  \
# title                  Multi-country monkeypox outbreak: situation up...
# Single Pathogen                                                Monkeypox
# Multiple Pathogens                                                   NaN
# Reporting Date                                                01-01-2022
# Reporting Agency                               World Health Organization
# Index Date                                                           NaN
# Case Count                                                          1310
# Death Count                                                            1
# Check Pathogen                                                       yes
# Location               European Region, African Region, Region of the...
# Multiple Locations     [[52.24764975, 5.541246849406163], [37.7320286...
# Risk Factors           - Confirmation of cases among men who have had...
# Modes of Transmission                                        None noted.
# Start                                                                 no
# R0                                                            [0.8, 1.0]
# URL                    https://www.who.int/emergencies/disease-outbre...
#
#                                                              2022-DON398  \
# title                  Ebola virus disease - Democratic Republic of t...
# Single Pathogen                                Ebola virus disease (EVD)
# Multiple Pathogens                                                   NaN
# Reporting Date                                                04-23-2022
# Reporting Agency       Ministry of Health (MoH) of the Democratic Rep...
# Index Date                                                    04-23-2022
# Case Count                                                             5
# Death Count                                                            5
# Check Pathogen                                                       yes
# Location               Democratic Republic of the Congo, Mbandaka, Wa...
# Multiple Locations     [[-2.9814344, 23.8222636], [0.0470732, 18.2564...
# Risk Factors           - Exposure to an animal host or from persisten...
# Modes of Transmission                                        None noted.
# Start                                                                yes
# R0                                                            [1.5, 2.5]
# URL                    https://www.who.int/emergencies/disease-outbre...
#
#                                                              2022-DON400  \
# title                  Severe acute hepatitis of unknown aetiology in...
# Single Pathogen                                               Adenovirus
# Multiple Pathogens                                                   NaN
# Reporting Date                                                04-05-2022
# Reporting Agency                               World Health Organization
# Index Date                                                    04-05-2022
# Case Count                                                            90
# Death Count                                                            4
# Check Pathogen                                                       yes
# Location               Luxembourg, Costa Rica, United Kingdom of Grea...
# Multiple Locations     [[49.8158683, 6.1296751], [10.2735633, -84.073...
# Risk Factors           - The aetiology of the severe acute hepatitis ...
# Modes of Transmission                                        None noted.
# Start                                                                yes
# R0                                                            [1.0, 2.5]
# URL                    https://www.who.int/emergencies/disease-outbre...
#
#                                                              2022-DON401
# title                  Dengue in Rohingya refugee/Forcibly Displaced ...
# Single Pathogen                                                   Dengue
# Multiple Pathogens                                                   NaN
# Reporting Date                                                05-31-2022
# Reporting Agency       Institute of Epidemiology, Disease Control and...
# Index Date                                                    05-31-2022
# Case Count                                                          7687
# Death Count                                                            6
# Check Pathogen                                                       yes
# Location               Bangladesh, Cox’s Bazar district, Rohingya ref...
# Multiple Locations     [[24.4769288, 90.2934413], [21.176647099999997...
# Risk Factors           - Inadequate access to potable water or qualit...
# Modes of Transmission  - Mosquito vector breeding near human habitati...
# Start                                                                yes
# R0                                                            [1.8, 2.0]
# URL                    https://www.who.int/emergencies/disease-outbre...

# %%
prepped.T.merge(DONPages).to_csv("output/DONValidationTable.csv",index=False)

# %%
prepped = temp.loc[extracted,:]
prepped.to_csv('output/DONScrape.csv')
prepped.to_pickle('output/DONScrape.pickle')

# %%
def cleanAgencies(column):
    agencyCleaners = {'Ministry of Health Uganda and WHO':'Ministry of Health Uganda',
                     'Ministry of Health and Family Welfare, Bangladesh':'Ministry of Health and Family Welfare of Bangladesh',
                     'Ministry of Health and WHO':'World Health Organization',
                     'Nigeria Centre for Disease Control':'Nigeria Centre for Disease Control and Prevention',
                     'WHO':'World Health Organization'}
    cleanWord = lambda x: x.split("’")[0].replace('&','and')
    dropParentheses = lambda x: ' '.join([cleanWord(i) for i in x.split() if not i.startswith('(')])
    column = column.apply(dropParentheses)
    column = column.replace(agencyCleaners)
    return column

def cleanDiseases(column):
    diseaseCleaners = {'and Lassa virus':'Lassa virus',
                       'Avian Influenza A(H5)':'Avian Influenza A(H5N1)',
                       'Avian influenza A (H5N1) virus':'Avian Influenza A(H5N1)',
                       'Avian influenza A(H5) virus':'Avian Influenza A(H5N1)',
                       'Circulating vaccine-derived poliovirus type 2 (cVDPV2)':'Circulating Vaccine-Derived Poliovirus Type 2 (cVDPV2)',
                       'Dengue':'Dengue fever',
                       'Dengue virus (DENV)':'Dengue fever',
                       'Ebola Sudan virus (SUDV)':'Sudan ebolavirus (SUDV)',
                       'Ebola Virus Disease (EVD)':'Ebola virus disease (EVD)',
                       'Echovirus 11 (E-11)': 'Enterovirus (Echovirus-11 (E-11))',
                       'Influenza A (H5N1)':'Avian Influenza A(H5N1)',
                       'Influenza A(H1N1)v virus':'Avian Influenza A(H5N1)',
                       'Influenza A(H1N2) variant virus':'Influenza A(H1N2)',
                       'Influenza A(H1N2)v virus':'Influenza A(H1N2)',
                       'Influenza A(H5N1)':'Avian Influenza A(H5N1)',
                       'Legionella pneumophila':"Legionnaires' disease",
                       'Marburg virus disease':'Marburg Virus Disease (MVD)',
                       'Marburg virus disease (MVD)':'Marburg Virus Disease (MVD)',
                       'Middle East Respiratory Syndrome Coronavirus (MERS-CoV)':'Middle East respiratory syndrome coronavirus (MERS-CoV)',
                       'Nipah virus infection':'Nipah virus',
                       'Severe acute hepatitis of unknown aetiology in children':'Acute hepatitis of unknown aetiology',
                       'Sudan ebolavirus':'Sudan ebolavirus (SUDV)',
                       'Ebola disease caused by Sudan virus (SUDV)':'Sudan ebolavirus (SUDV)'}
    column = column.replace(diseaseCleaners)
    return column
                            
def addCaseFatalityRate(df):
    df['Case Count'] = pd.to_numeric(df['Case Count'], errors='coerce')
    df['Death Count'] = pd.to_numeric(df['Death Count'], errors='coerce').fillna(0)
    df['Case Fatality Rate'] = df['Death Count'] / df['Case Count']


def remapCategoricals(df):
    df.rename({'Start':'Status',
               'Check Pathogen':'Class',
               'title':'Title'},axis=1,inplace=True)
    df.Status = df.Status.map({'yes':'Novel outbreak','no':'Existing epidemic'})
    df.Class = df.Class.map({'yes':'Epidemic','no':'Syndemic'})
   
    
def rankSeverity(df):
    roughR0 = []
    for rEst in df['R0']:
        if type(rEst) is list:
            roughR0.append(np.mean(rEst))
        else:
            roughR0.append(1.)
    df['Rough R0'] = roughR0
    df['Severity'] = 4 + (10 * df['Case Count'] * (1+20*df['Case Fatality Rate']) * df['Rough R0'] / df['Countries Affected']) ** .25
    df['R0'] = df['R0'].astype(str)

    
    
def standardizePathogens(df):
    pathogens = []
    for singPath, multPath in zip(df['Single Pathogen'],df['Multiple Pathogens']):
        if singPath == singPath:
            pathogens.append(singPath)
        elif multPath == multPath:
            multPath = multPath.split('[')[1].split(']')[0]
            multPath = ast.literal_eval(f'[{multPath}]')
            if len(multPath) == 1:
                pathogens.append(multPath[0])
            elif len(multPath) > 3:
                pathogens.append(', '.join(multPath[:3] + ['etc']))
            else:
                multPath[-1] = 'and ' + multPath[-1]
                pathogens.append((', ').join(multPath))
    df['Pathogen(s)'] = pathogens
    df = df.drop(['Single Pathogen','Multiple Pathogens'],axis=1)
    
    return df



def expandLocations(df):
    newRows = []
    multRowDf = df.dropna(subset=['Multiple Locations'])
    for index, row in multRowDf.iterrows():
        locNames = row['Location'].split(', ')
        locCoords = row['Multiple Locations']
        sublocCount = len(locNames)
        
        for locName, locCoord in zip(locNames,locCoords):
            newRow = {**row}
            newRow['Single Location'] = locCoord
            newRows.append(newRow)
            
    df = pd.concat([df,pd.DataFrame(newRows)])
    df = df.dropna(subset=['Single Location'])
    
    df['Latitude'] = df['Single Location'].str[0]
    df['Longitude'] = df['Single Location'].str[1]
    
    df = df.drop(['Multiple Locations','Single Location'],axis=1)


    return df
        
            
def mergeSublocations(df):
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))[['pop_est','name','geometry']]
    pointsDf = gpd.GeoDataFrame(df,geometry=gpd.points_from_xy(df['Longitude'], df['Latitude'])).set_crs('EPSG:4326')
    merged = gpd.sjoin(pointsDf, world, how='left', predicate='within')
    merged = merged.drop(['index_right'],axis=1)
    merged = merged.rename({'pop_est':'Population',
                            'name':'Country'},
                           axis=1)
    
    merged = merged.dropna(subset=['Country'])
    merged = merged.groupby(['DON','Country']).last().reset_index()
    sublocCounts = merged.groupby(['DON']).Country.count().reset_index()
    sublocCounts.columns = ['DON','Countries Affected']
    merged = pd.merge(merged, sublocCounts, how='left')    
    
    return merged

        
            

def prepPlotDf(dfIn):
    df = dfIn.copy(deep=True).T
    df['DON'] = df.index
    
    df['Reporting Agency'] = cleanAgencies(df['Reporting Agency'])
    df['Single Pathogen'] = cleanDiseases(df['Single Pathogen'])
    
    df = standardizePathogens(df)
    df = expandLocations(df)
    df = mergeSublocations(df)
    
    remapCategoricals(df)
    addCaseFatalityRate(df)
    rankSeverity(df)
    
    df.Severity = df.Severity.fillna(df.Severity.median())
    
    df['Coord'] = df.Latitude.astype(str) + ',' + df.Longitude.astype(str)
    
    df['Summary'] = 'Country:\n' + df['Country'] + '\n\nEvent Type:\n' + df['Status']+' - '+df['Class'] + '\n\nNumber of Countries Affected:\n' + df['Countries Affected'].astype(str) + '\n\nReporting Agency:\n' + df['Reporting Agency'] + '\n\nModes of Transmission:\n' + df['Modes of Transmission'] + '\n\nRisk Factors:\n' + df['Risk Factors']
    
    return df

    
processed = prepPlotDf(prepped)
# Out:
# /var/folders/pk/jw21zwnj07z_f216pyxkfynw0000gn/T/ipykernel_11881/3337615268.py:115: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))[['pop_est','name','geometry']]

# %%
processed.drop(['geometry'],axis=1).to_csv('output/DONPrepped.csv',index=False)
processed.to_file('output/DONPrepped.geojson', driver='GeoJSON')

# %%
print(processed.loc[0,'Summary'])
# Out:
# Country:
# Cameroon
#
# Event Type:
# Novel outbreak - Epidemic
#
# Number of Countries Affected:
# 12
#
# Reporting Agency:
# World Health Organization
#
# Modes of Transmission:
# - Direct contact with infected person
# - Sexual contact with infected person
# - Contact with sick mammals harboring Monkeypox virus
#
# Risk Factors:
# - Frequent encounters between persons in close proximity or with physical contact
# - Inadequate infection prevention and control measures by health workers, or not wearing appropriate personal protective equipment
# - Being a member of a vulnerable group, such as children, immunocompromised individuals, or potentially pregnant women.

# %%
processed.iloc[0]
# Out:
# DON                                                            2022-DON390
# Country                                                           Cameroon
# Title                    Multi-country monkeypox outbreak: situation up...
# Reporting Date                                                  05-13-2022
# Reporting Agency                                 World Health Organization
# Index Date                                                      05-13-2022
# Case Count                                                             523
# Death Count                                                             66
# Class                                                             Epidemic
# Location                 Europe, North America, Nigeria, WHO European R...
# Risk Factors             - Frequent encounters between persons in close...
# Modes of Transmission    - Direct contact with infected person\n- Sexua...
# Status                                                      Novel outbreak
# R0                                                              [0.8, 1.0]
# URL                      https://www.who.int/emergencies/disease-outbre...
# Pathogen(s)                                                      Monkeypox
# Latitude                                                          4.612552
# Longitude                                                        13.153581
# geometry                                      POINT (13.1535811 4.6125522)
# Population                                                      25876380.0
# Countries Affected                                                      12
# Case Fatality Rate                                                0.126195
# Rough R0                                                               0.9
# Severity                                                         10.097428
# Coord                                                 4.6125522,13.1535811
# Summary                  Country:\nCameroon\n\nEvent Type:\nNovel outbr...
# Name: 0, dtype: object

# %%
fig, ax = plt.subplots(figsize=(20,14))
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))[['pop_est','name','geometry']]
world.plot(ax=ax,
          zorder=1,
          alpha=.3)

processed.plot(ax=ax,
               zorder=2,
               column='Pathogen(s)',
               cmap='gist_ncar',
               markersize='Severity',
               legend=True,
               legend_kwds={'loc': 'lower right'})

leg = ax.get_legend()
leg.set_bbox_to_anchor((1.5, -.05, 0., 0.))

plt.title("Mapped DON Events by Country")
# Out:
# /var/folders/pk/jw21zwnj07z_f216pyxkfynw0000gn/T/ipykernel_11881/1991126947.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))[['pop_est','name','geometry']]
# Text(0.5, 1.0, 'Mapped DON Events by Country')
